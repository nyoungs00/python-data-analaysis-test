# %%
print("hello~!")
# Out:
# 'Python 3.12.13'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 필요한 패키지를 사용하여 <a href='command:jupyter.createPythonEnvAndSelectController'>Python 환경 만들기</a>
#
# 또는 다음 명령을 사용하여 'ipykernel'을(를) 설치합니다. 'c:/Users/user/.local/bin/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("두번째 블록!!!!")
# Out:
# 'Python 3.12.13'(으)로 셀을 실행하려면 ipykernel 패키지가 필요합니다.
#
# 필요한 패키지를 사용하여 <a href='command:jupyter.createPythonEnvAndSelectController'>Python 환경 만들기</a>
#
# 또는 다음 명령을 사용하여 'ipykernel'을(를) 설치합니다. 'c:/Users/user/.local/bin/python3.12.exe -m pip install ipykernel -U --user --force-reinstall'
